# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

x = np.array([1,5])
y = np.array([50,85])

plt.plot(x,y)
plt.show()

# %% [markdown]
# # Type of Plots :

# %% [markdown]
# #  1. Line Chart

# %%
import matplotlib.pyplot as plt 
import pandas as pd

# %%
points = np.array([1,5,80,1,45,65])
plt.plot(points)
plt.show()

# %%
points = np.array([1,5,80,1,45,65])
plt.plot(points, linestyle = 'dotted')
plt.show()

# %%
points = np.array([1,5,80,1,45,65])
plt.plot(points , linestyle = 'dashed')
plt.show()

# %% [markdown]
# # 2. bar Chart :

# %%
x = (['x','y','w','h'])
y = ([25,60,5,54])

plt.bar(x,y)
plt.show()

# %% [markdown]
# # 3 .Scatter Plot :

# %%
X1 = ([50,6,12,14,75])
Y1 = ([58,65,22,31,12])

plt.scatter(X1 , Y1)
plt.show()

# %% [markdown]
# # 4. pie Plot :

# %%
H1 = ([50,21,23,25,8])
plt.pie(H1)
# Out:
# ([<matplotlib.patches.Wedge at 0x221e55db010>,
# ...
#  [Text(0.3605539022105265, 1.0392309096638543, ''),
#   Text(-1.0879062636045262, 0.16266518253774928, ''),
#   Text(-0.648763249975916, -0.888316523250968, ''),
#   Text(0.5811152448922382, -0.9339727363011375, ''),
#   Text(1.0785307157393336, -0.2162671847664388, '')])

# %% [markdown]
# # 5 . histogram :

# %%
D1 = np.random.normal(52,32,20)
plt.hist(D1)
# Out:
# (array([4., 1., 2., 2., 3., 1., 4., 1., 1., 1.]),
#  array([ 10.92349811,  22.70364253,  34.48378694,  46.26393136,
#          58.04407577,  69.82422019,  81.6043646 ,  93.38450902,
#         105.16465343, 116.94479785, 128.72494226]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # Seaborn :

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# #  1 .Boxplot :

# %%
# inbuilt dataset in seaborn laibrery : 
df = sns.load_dataset("tips")

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.boxplot(by = 'day' , column = ['total_bill'] , grid = False)
# Out:
# <Axes: title={'center': 'total_bill'}, xlabel='day'>

# %% [markdown]
# # 2 .Displot :

# %%
# inbuilt dataset in seaborn laibrery : 
titanic = sns.load_dataset("titanic")

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
age1 = titanic['age']. dropna()
print = age1.head()
sns.displot(age1 , bins = 30 ,kde = False )
plt.show()

# %% [markdown]
# # 3. regplot :

# %%
# inbuilt dataset in seaborn laibrery : 
data = sns.load_dataset('mpg')

# %%
data.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
sns.regplot(x='mpg' ,y = 'displacement' , data = data)
plt.show()
